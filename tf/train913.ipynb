# %% [markdown]
# # 以相似度为训练目标

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ## 训练数据生成器

# %%
# !git clone https://github.com/daibiaoxuwu/3182
# !git clone https://github.com/daibiaoxuwu/3182b
# Out:
# Cloning into '3182'...
# remote: Enumerating objects: 58593, done.
# remote: Counting objects: 100% (58593/58593), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 58593 (delta 58585), reused 58593 (delta 58585), pack-reused 0
# Receiving objects: 100% (58593/58593), 24.11 MiB | 7.50 MiB/s, done.
# Resolving deltas: 100% (58585/58585), done.
# Checking out files: 100% (58591/58591), done.
# Cloning into '3182b'...
# remote: Enumerating objects: 160, done.
# remote: Counting objects: 100% (160/160), done.
# remote: Compressing objects: 100% (160/160), done.
# remote: Total 160 (delta 0), reused 160 (delta 0), pack-reused 0
# Receiving objects: 100% (160/160), 862.78 KiB | 724.00 KiB/s, done.

# %%
import os
import cv2
import numpy as np
import random
from matplotlib import pyplot as plt

datasizex = 7
datasizey = 7
picsizex = 10
picsizey = 47
picnum = 30
lowpercent = 125.0
highpercent = 233.0
enhance = 4
def read_data(path1,path2):

  x_train0 = []
  y_train0 = dict()
  idxes = dict()

  #read clock
  #read and /255
  for filename in os.listdir(path2):
      if 'git' in filename: continue
      ans = cv2.imread(os.path.join(path2,filename),cv2.IMREAD_GRAYSCALE).astype('float32')     
      ans = np.clip((ans-lowpercent)/(highpercent - lowpercent),0,1)
      y_train0[int(filename[:-4])]=ans

  keys = list(y_train0.keys())
  
  #read data
  #add an axis and /255
  
  filelist = os.listdir(path1)
  random.shuffle(filelist)
  index = 0
  for filename in filelist:
      if 'git' in filename or 'c.jpg' in filename: continue
      ##################################
      ##################################
      ##################################
      ##################################
      ##################################
      ftime = int(filename.split('_')[0])
      ##################################
      ##################################
      ##################################
      ##################################
      ##################################
      value = max(filter(lambda t:t<ftime,keys))
      if(abs(ftime-value)<3000):continue

      x_train0.append(cv2.imread(os.path.join(path1,filename)).astype('float32')/255.0)
      if value not in idxes:idxes[value]=[index]
      else: idxes[value].append(index)
      index += 1

  #index data
  print(len(x_train0),index,len(y_train0),len(idxes.keys()))
  lens = [len(i) for i in idxes.values()]
  print(min(lens),max(lens),np.average(lens))
  for key,val in list(idxes.items()):
    if len(val)<picnum:
      idxes.pop(key)
  

  #generator
  def data_generator(ikeys_t):
    while True:
      dataout = []
      for i in range(picnum):dataout.append([])
      ansout = []
      for train2 in range(32):
        '''
        while True:
          key = random.choice(ikeys_t)
          idx2 = random.sample(idxes[key],picnum)
          posx = random.randint(0,picsizex-datasizex)
          posy = random.randint(0,picsizey-datasizey)
          pic = x_train0[idx2[i]][posx:posx+datasizex,posy:posy+datasizey,:]
          if(np.sum(pic) < 175):
            for i in range(picnum):
              dataout[i].append(x_train0[idx2[i]][posx:posx+datasizex,posy:posy+datasizey,:])
            ansout.append(y_train0[key][posx:posx+datasizex,posy:posy+datasizey])
            break
        '''
        key = random.choice(ikeys_t)
        idx2 = random.sample(idxes[key],picnum)
        posx = random.randint(0,picsizex-datasizex)
        posy = random.randint(0,picsizey-datasizey)
        pic = x_train0[idx2[i]][posx:posx+datasizex,posy:posy+datasizey,:]
        for i in range(picnum):
          dataout[i].append(x_train0[idx2[i]][posx:posx+datasizex,posy:posy+datasizey,:])
        ansout.append(y_train0[key][posx*enhance:(posx+datasizex)*enhance,posy*enhance:(posy+datasizey)*enhance])
      yield [np.stack(data2) for data2 in dataout],np.stack(ansout)
  def pic_generator(ikeys_t):
    while True:
      key = random.choice(ikeys_t)
      idx2 = random.sample(idxes[key],picnum)
      data=[x_train0[i] for i in idx2]
      ans=y_train0[key]
      yield data,ans

  #split
  ikeys = list(idxes.keys())
  random.shuffle(ikeys)
  ltrain = int(len(ikeys)*0.8)  
  train_generator = data_generator(ikeys[:ltrain])
  test_generator = data_generator(ikeys[ltrain:])
  train_pic_generator = pic_generator(ikeys[:ltrain])
  test_pic_generator = pic_generator(ikeys[ltrain:])

  return train_generator,test_generator,train_pic_generator,test_pic_generator

# %%
from matplotlib import pyplot as plt
train_generator,test_generator,train_pic_generator,test_pic_generator = read_data('3182','3182b')
# Out:
# 55630 55630 344 305
# 117 211 182.39344262295083

# %%
data,ans = next(train_generator)
for pics in data:
  for i in range(6):
    plt.subplot(231+i)
    plt.imshow(pics[i,:,:,0],cmap='gray')
ans[0,0,0]=0
ans[0,1,0]=1
plt.imshow(ans[0],cmap='gray')
print(np.sum(ans[0]))
print(np.min(ans[0]),np.max(ans[0]))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.
# 614.6482
# 0.0 1.0

# %% [markdown]
# # 数据初始化完成。

# %% [markdown]
# # 装载Tensorflow

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# 安装 TensorFlow
try:
  # Colab only
  # %tensorflow_version 2.x
except Exception:
    pass

import tensorflow as tf
# Out:
# TensorFlow 2.x selected.

# %% [markdown]
# # 搭建模型和训练
# 现在的网络去掉dropout则可以拟合10张图片，
# 但是加上dropout就拟合不了。
# 从7张拟合5张的，则可以在两个epoch（每个epoch抽取60000次）内到80%。
#
# 继续训练20张，一个epoch就到60%。

# %%
inputs = [tf.keras.layers.Input(shape=(datasizex,datasizey,3))  for i in range(picnum)]
#inputs = tf.keras.layers.Input(shape=(5,12,12,1))
convg1 = 0
convd1 = 0
convh1 = inputs
inputs_big = inputs
for layernum in range(5):
  conv_a1 = tf.keras.layers.Conv2D(32, (3, 3), padding = 'Same',  activation='relu')
  conva1 = [conv_a1(convh1[i]) for i in range(picnum)]
  #drop_a1 = tf.keras.layers.Dropout(0.2)
  #conva1 = drop_a1(conva1)
  conv_b1 = tf.keras.layers.Conv2D(32, (3, 3), padding = 'Same',  activation='relu')
  convb1 = [conv_b1(conva1[i]) for i in range(picnum)]
  

  conv_c1 = tf.keras.layers.Conv2D(32, (3, 3), padding = 'Same',  activation='relu')
  convc1 = [conv_c1(inputs_big[i]) for i in range(picnum)]
  #drop_b1 = tf.keras.layers.Dropout(0.2)
  #convc1 = drop_a1(convc1)
  conv_d1 = tf.keras.layers.Conv2D(32, (3, 3), padding = 'Same',  activation='relu')
  convd1 = [conv_d1(convc1[i]) for i in range(picnum)]
  

  convs1 = tf.stack(convb1)
  convf1 = [
      tf.math.reduce_max(convs1, axis=[0]),
      tf.math.reduce_mean(convs1, axis=[0]),
      tf.math.reduce_min(convs1, axis=[0]),
  ]

  conv_g1 = tf.keras.layers.Conv2D(32, (3, 3), padding = 'Same',  activation='relu')
  convg1 = [conv_g1(convf1[i]) for i in range(3)]

  drop_c1 = tf.keras.layers.Dropout(0.2)
  convh1 = [drop_c1(tf.concat(convg1+[convd1[i]],axis=3)) for i in range(picnum)]
  if(layernum % 2 == 1):
    convex1 = tf.keras.layers.Conv2D(32, (1, 1), padding = 'Same',  activation='relu')
    convh1 = [tf.keras.layers.UpSampling2D(size=(2, 2), data_format=None)(i) for i in convh1]
    convh1 = [convex1(convh1[i]) for i in range(picnum)]
    inputs_big = [tf.keras.layers.UpSampling2D(size=(2, 2), data_format=None)(i) for i in inputs_big]
convh3 = tf.concat(convg1+convd1,axis=3)

convx1 = tf.keras.layers.Conv2D(64, (3, 3), padding = 'Same',  activation='relu')(convh3)
convx2 = tf.keras.layers.Dropout(0.2)(convx1)
convx3 = tf.keras.layers.Conv2D(64, (3, 3), padding = 'Same', activation='relu')(convx2)
'''
convx3 = tf.keras.layers.Flatten()(convx2)

#keep_prob = tf.placeholder(tf.float32) # dropout (keep probability)
convx4 = tf.keras.layers.Dropout(0.2)(convx3)

convy1 = tf.keras.layers.Dense(21*45)(convx4)
#convy3 = tf.keras.layers.Dense(10,activation='softmax')(convy1)
convy4 = tf.keras.layers.Reshape([21,45])(convy1)
'''

convx4 = tf.keras.layers.Conv2D(1, (3, 3), padding = 'Same')(convx3)

model = tf.keras.Model(inputs=inputs, outputs=convx4)

# %%
#tf.reduce_mean(tf.image.ssim(reconstructed, truth, 1.0))
model.compile(optimizer='adam',#tf.keras.optimizers.Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0),
                #loss=lambda y_pred,y_true:1-tf.reduce_mean(tf.image.ssim_multiscale(tf.clip_by_value(y_pred,0,1), y_true, 255))#-tf.reduce_mean(tf.image.psnr(tf.clip_by_value(y_pred,0,1), y_true, 1.0))
              loss='mse',
              metrics=['mse']
              )
            
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_13 (InputLayer)           [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_14 (InputLayer)           [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_15 (InputLayer)           [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_17 (InputLayer)           [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_18 (InputLayer)           [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_19 (InputLayer)           [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_20 (InputLayer)           [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_21 (InputLayer)           [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_22 (InputLayer)           [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_23 (InputLayer)           [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_24 (InputLayer)           [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_25 (InputLayer)           [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_26 (InputLayer)           [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_27 (InputLayer)           [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_28 (InputLayer)           [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_29 (InputLayer)           [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# input_30 (InputLayer)           [(None, 7, 7, 3)]    0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 7, 7, 32)     896         input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
#                                                                  input_4[0][0]
#                                                                  input_5[0][0]
#                                                                  input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
#                                                                  input_9[0][0]
#                                                                  input_10[0][0]
#                                                                  input_11[0][0]
#                                                                  input_12[0][0]
#                                                                  input_13[0][0]
#                                                                  input_14[0][0]
#                                                                  input_15[0][0]
#                                                                  input_16[0][0]
#                                                                  input_17[0][0]
#                                                                  input_18[0][0]
#                                                                  input_19[0][0]
#                                                                  input_20[0][0]
#                                                                  input_21[0][0]
#                                                                  input_22[0][0]
#                                                                  input_23[0][0]
#                                                                  input_24[0][0]
#                                                                  input_25[0][0]
#                                                                  input_26[0][0]
#                                                                  input_27[0][0]
#                                                                  input_28[0][0]
#                                                                  input_29[0][0]
#                                                                  input_30[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 7, 7, 32)     9248        conv2d[0][0]
#                                                                  conv2d[1][0]
#                                                                  conv2d[2][0]
#                                                                  conv2d[3][0]
#                                                                  conv2d[4][0]
#                                                                  conv2d[5][0]
#                                                                  conv2d[6][0]
#                                                                  conv2d[7][0]
#                                                                  conv2d[8][0]
#                                                                  conv2d[9][0]
#                                                                  conv2d[10][0]
#                                                                  conv2d[11][0]
#                                                                  conv2d[12][0]
#                                                                  conv2d[13][0]
#                                                                  conv2d[14][0]
#                                                                  conv2d[15][0]
#                                                                  conv2d[16][0]
#                                                                  conv2d[17][0]
#                                                                  conv2d[18][0]
#                                                                  conv2d[19][0]
#                                                                  conv2d[20][0]
#                                                                  conv2d[21][0]
#                                                                  conv2d[22][0]
#                                                                  conv2d[23][0]
#                                                                  conv2d[24][0]
#                                                                  conv2d[25][0]
#                                                                  conv2d[26][0]
#                                                                  conv2d[27][0]
#                                                                  conv2d[28][0]
#                                                                  conv2d[29][0]
# __________________________________________________________________________________________________
# tf_op_layer_stack (TensorFlowOp [(30, None, 7, 7, 32 0           conv2d_1[0][0]
#                                                                  conv2d_1[1][0]
#                                                                  conv2d_1[2][0]
#                                                                  conv2d_1[3][0]
#                                                                  conv2d_1[4][0]
#                                                                  conv2d_1[5][0]
#                                                                  conv2d_1[6][0]
#                                                                  conv2d_1[7][0]
#                                                                  conv2d_1[8][0]
#                                                                  conv2d_1[9][0]
#                                                                  conv2d_1[10][0]
#                                                                  conv2d_1[11][0]
#                                                                  conv2d_1[12][0]
#                                                                  conv2d_1[13][0]
#                                                                  conv2d_1[14][0]
#                                                                  conv2d_1[15][0]
#                                                                  conv2d_1[16][0]
#                                                                  conv2d_1[17][0]
#                                                                  conv2d_1[18][0]
#                                                                  conv2d_1[19][0]
#                                                                  conv2d_1[20][0]
#                                                                  conv2d_1[21][0]
#                                                                  conv2d_1[22][0]
#                                                                  conv2d_1[23][0]
#                                                                  conv2d_1[24][0]
#                                                                  conv2d_1[25][0]
#                                                                  conv2d_1[26][0]
#                                                                  conv2d_1[27][0]
#                                                                  conv2d_1[28][0]
#                                                                  conv2d_1[29][0]
# __________________________________________________________________________________________________
# tf_op_layer_Max (TensorFlowOpLa [(None, 7, 7, 32)]   0           tf_op_layer_stack[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean (TensorFlowOpL [(None, 7, 7, 32)]   0           tf_op_layer_stack[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Min (TensorFlowOpLa [(None, 7, 7, 32)]   0           tf_op_layer_stack[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 7, 7, 32)     896         input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
#                                                                  input_4[0][0]
#                                                                  input_5[0][0]
#                                                                  input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
#                                                                  input_9[0][0]
#                                                                  input_10[0][0]
#                                                                  input_11[0][0]
#                                                                  input_12[0][0]
#                                                                  input_13[0][0]
#                                                                  input_14[0][0]
#                                                                  input_15[0][0]
#                                                                  input_16[0][0]
#                                                                  input_17[0][0]
#                                                                  input_18[0][0]
#                                                                  input_19[0][0]
#                                                                  input_20[0][0]
#                                                                  input_21[0][0]
#                                                                  input_22[0][0]
#                                                                  input_23[0][0]
#                                                                  input_24[0][0]
#                                                                  input_25[0][0]
#                                                                  input_26[0][0]
#                                                                  input_27[0][0]
#                                                                  input_28[0][0]
#                                                                  input_29[0][0]
#                                                                  input_30[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 7, 7, 32)     9248        tf_op_layer_Max[0][0]
#                                                                  tf_op_layer_Mean[0][0]
#                                                                  tf_op_layer_Min[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 7, 7, 32)     9248        conv2d_2[0][0]
#                                                                  conv2d_2[1][0]
#                                                                  conv2d_2[2][0]
#                                                                  conv2d_2[3][0]
#                                                                  conv2d_2[4][0]
#                                                                  conv2d_2[5][0]
#                                                                  conv2d_2[6][0]
#                                                                  conv2d_2[7][0]
#                                                                  conv2d_2[8][0]
#                                                                  conv2d_2[9][0]
#                                                                  conv2d_2[10][0]
#                                                                  conv2d_2[11][0]
#                                                                  conv2d_2[12][0]
#                                                                  conv2d_2[13][0]
#                                                                  conv2d_2[14][0]
#                                                                  conv2d_2[15][0]
#                                                                  conv2d_2[16][0]
#                                                                  conv2d_2[17][0]
#                                                                  conv2d_2[18][0]
#                                                                  conv2d_2[19][0]
#                                                                  conv2d_2[20][0]
#                                                                  conv2d_2[21][0]
#                                                                  conv2d_2[22][0]
#                                                                  conv2d_2[23][0]
#                                                                  conv2d_2[24][0]
#                                                                  conv2d_2[25][0]
#                                                                  conv2d_2[26][0]
#                                                                  conv2d_2[27][0]
#                                                                  conv2d_2[28][0]
#                                                                  conv2d_2[29][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat (TensorFlowO [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_1 (TensorFlo [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_2 (TensorFlo [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_3 (TensorFlo [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[3][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_4 (TensorFlo [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[4][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_5 (TensorFlo [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[5][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_6 (TensorFlo [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[6][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_7 (TensorFlo [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[7][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_8 (TensorFlo [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[8][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_9 (TensorFlo [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[9][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_10 (TensorFl [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[10][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_11 (TensorFl [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[11][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_12 (TensorFl [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[12][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_13 (TensorFl [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[13][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_14 (TensorFl [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[14][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_15 (TensorFl [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[15][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_16 (TensorFl [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[16][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_17 (TensorFl [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[17][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_18 (TensorFl [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[18][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_19 (TensorFl [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[19][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_20 (TensorFl [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[20][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_21 (TensorFl [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[21][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_22 (TensorFl [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[22][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_23 (TensorFl [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[23][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_24 (TensorFl [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[24][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_25 (TensorFl [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[25][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_26 (TensorFl [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[26][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_27 (TensorFl [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[27][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_28 (TensorFl [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[28][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_29 (TensorFl [(None, 7, 7, 128)]  0           conv2d_4[0][0]
#                                                                  conv2d_4[1][0]
#                                                                  conv2d_4[2][0]
#                                                                  conv2d_3[29][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 7, 7, 128)    0           tf_op_layer_concat[0][0]
#                                                                  tf_op_layer_concat_1[0][0]
#                                                                  tf_op_layer_concat_2[0][0]
#                                                                  tf_op_layer_concat_3[0][0]
#                                                                  tf_op_layer_concat_4[0][0]
#                                                                  tf_op_layer_concat_5[0][0]
#                                                                  tf_op_layer_concat_6[0][0]
#                                                                  tf_op_layer_concat_7[0][0]
#                                                                  tf_op_layer_concat_8[0][0]
#                                                                  tf_op_layer_concat_9[0][0]
#                                                                  tf_op_layer_concat_10[0][0]
#                                                                  tf_op_layer_concat_11[0][0]
#                                                                  tf_op_layer_concat_12[0][0]
#                                                                  tf_op_layer_concat_13[0][0]
#                                                                  tf_op_layer_concat_14[0][0]
#                                                                  tf_op_layer_concat_15[0][0]
#                                                                  tf_op_layer_concat_16[0][0]
#                                                                  tf_op_layer_concat_17[0][0]
#                                                                  tf_op_layer_concat_18[0][0]
#                                                                  tf_op_layer_concat_19[0][0]
#                                                                  tf_op_layer_concat_20[0][0]
#                                                                  tf_op_layer_concat_21[0][0]
#                                                                  tf_op_layer_concat_22[0][0]
#                                                                  tf_op_layer_concat_23[0][0]
#                                                                  tf_op_layer_concat_24[0][0]
#                                                                  tf_op_layer_concat_25[0][0]
#                                                                  tf_op_layer_concat_26[0][0]
#                                                                  tf_op_layer_concat_27[0][0]
#                                                                  tf_op_layer_concat_28[0][0]
#                                                                  tf_op_layer_concat_29[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 7, 7, 32)     36896       dropout[0][0]
#                                                                  dropout[1][0]
#                                                                  dropout[2][0]
#                                                                  dropout[3][0]
#                                                                  dropout[4][0]
#                                                                  dropout[5][0]
#                                                                  dropout[6][0]
#                                                                  dropout[7][0]
#                                                                  dropout[8][0]
#                                                                  dropout[9][0]
#                                                                  dropout[10][0]
#                                                                  dropout[11][0]
#                                                                  dropout[12][0]
#                                                                  dropout[13][0]
#                                                                  dropout[14][0]
#                                                                  dropout[15][0]
#                                                                  dropout[16][0]
#                                                                  dropout[17][0]
#                                                                  dropout[18][0]
#                                                                  dropout[19][0]
#                                                                  dropout[20][0]
#                                                                  dropout[21][0]
#                                                                  dropout[22][0]
#                                                                  dropout[23][0]
#                                                                  dropout[24][0]
#                                                                  dropout[25][0]
#                                                                  dropout[26][0]
#                                                                  dropout[27][0]
#                                                                  dropout[28][0]
#                                                                  dropout[29][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 7, 7, 32)     9248        conv2d_5[0][0]
#                                                                  conv2d_5[1][0]
#                                                                  conv2d_5[2][0]
#                                                                  conv2d_5[3][0]
#                                                                  conv2d_5[4][0]
#                                                                  conv2d_5[5][0]
#                                                                  conv2d_5[6][0]
#                                                                  conv2d_5[7][0]
#                                                                  conv2d_5[8][0]
#                                                                  conv2d_5[9][0]
#                                                                  conv2d_5[10][0]
#                                                                  conv2d_5[11][0]
#                                                                  conv2d_5[12][0]
#                                                                  conv2d_5[13][0]
#                                                                  conv2d_5[14][0]
#                                                                  conv2d_5[15][0]
#                                                                  conv2d_5[16][0]
#                                                                  conv2d_5[17][0]
#                                                                  conv2d_5[18][0]
#                                                                  conv2d_5[19][0]
#                                                                  conv2d_5[20][0]
#                                                                  conv2d_5[21][0]
#                                                                  conv2d_5[22][0]
#                                                                  conv2d_5[23][0]
#                                                                  conv2d_5[24][0]
#                                                                  conv2d_5[25][0]
#                                                                  conv2d_5[26][0]
#                                                                  conv2d_5[27][0]
#                                                                  conv2d_5[28][0]
#                                                                  conv2d_5[29][0]
# __________________________________________________________________________________________________
# tf_op_layer_stack_1 (TensorFlow [(30, None, 7, 7, 32 0           conv2d_6[0][0]
#                                                                  conv2d_6[1][0]
#                                                                  conv2d_6[2][0]
#                                                                  conv2d_6[3][0]
#                                                                  conv2d_6[4][0]
#                                                                  conv2d_6[5][0]
#                                                                  conv2d_6[6][0]
#                                                                  conv2d_6[7][0]
#                                                                  conv2d_6[8][0]
#                                                                  conv2d_6[9][0]
#                                                                  conv2d_6[10][0]
#                                                                  conv2d_6[11][0]
#                                                                  conv2d_6[12][0]
# ...
# __________________________________________________________________________________________________
# up_sampling2d_98 (UpSampling2D) (None, 28, 28, 3)    0           up_sampling2d_38[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_99 (UpSampling2D) (None, 28, 28, 3)    0           up_sampling2d_39[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_100 (UpSampling2D (None, 28, 28, 3)    0           up_sampling2d_40[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_101 (UpSampling2D (None, 28, 28, 3)    0           up_sampling2d_41[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_102 (UpSampling2D (None, 28, 28, 3)    0           up_sampling2d_42[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_103 (UpSampling2D (None, 28, 28, 3)    0           up_sampling2d_43[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_104 (UpSampling2D (None, 28, 28, 3)    0           up_sampling2d_44[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_105 (UpSampling2D (None, 28, 28, 3)    0           up_sampling2d_45[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_106 (UpSampling2D (None, 28, 28, 3)    0           up_sampling2d_46[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_107 (UpSampling2D (None, 28, 28, 3)    0           up_sampling2d_47[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_108 (UpSampling2D (None, 28, 28, 3)    0           up_sampling2d_48[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_109 (UpSampling2D (None, 28, 28, 3)    0           up_sampling2d_49[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_110 (UpSampling2D (None, 28, 28, 3)    0           up_sampling2d_50[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_111 (UpSampling2D (None, 28, 28, 3)    0           up_sampling2d_51[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_112 (UpSampling2D (None, 28, 28, 3)    0           up_sampling2d_52[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_113 (UpSampling2D (None, 28, 28, 3)    0           up_sampling2d_53[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_114 (UpSampling2D (None, 28, 28, 3)    0           up_sampling2d_54[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_115 (UpSampling2D (None, 28, 28, 3)    0           up_sampling2d_55[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_116 (UpSampling2D (None, 28, 28, 3)    0           up_sampling2d_56[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_117 (UpSampling2D (None, 28, 28, 3)    0           up_sampling2d_57[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_118 (UpSampling2D (None, 28, 28, 3)    0           up_sampling2d_58[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_119 (UpSampling2D (None, 28, 28, 3)    0           up_sampling2d_59[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Max_4 (TensorFlowOp [(None, 28, 28, 32)] 0           tf_op_layer_stack_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_4 (TensorFlowO [(None, 28, 28, 32)] 0           tf_op_layer_stack_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Min_4 (TensorFlowOp [(None, 28, 28, 32)] 0           tf_op_layer_stack_4[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 28, 28, 32)   896         up_sampling2d_90[0][0]
#                                                                  up_sampling2d_91[0][0]
#                                                                  up_sampling2d_92[0][0]
#                                                                  up_sampling2d_93[0][0]
#                                                                  up_sampling2d_94[0][0]
#                                                                  up_sampling2d_95[0][0]
#                                                                  up_sampling2d_96[0][0]
#                                                                  up_sampling2d_97[0][0]
#                                                                  up_sampling2d_98[0][0]
#                                                                  up_sampling2d_99[0][0]
#                                                                  up_sampling2d_100[0][0]
#                                                                  up_sampling2d_101[0][0]
#                                                                  up_sampling2d_102[0][0]
#                                                                  up_sampling2d_103[0][0]
#                                                                  up_sampling2d_104[0][0]
#                                                                  up_sampling2d_105[0][0]
#                                                                  up_sampling2d_106[0][0]
#                                                                  up_sampling2d_107[0][0]
#                                                                  up_sampling2d_108[0][0]
#                                                                  up_sampling2d_109[0][0]
#                                                                  up_sampling2d_110[0][0]
#                                                                  up_sampling2d_111[0][0]
#                                                                  up_sampling2d_112[0][0]
#                                                                  up_sampling2d_113[0][0]
#                                                                  up_sampling2d_114[0][0]
#                                                                  up_sampling2d_115[0][0]
#                                                                  up_sampling2d_116[0][0]
#                                                                  up_sampling2d_117[0][0]
#                                                                  up_sampling2d_118[0][0]
#                                                                  up_sampling2d_119[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 28, 28, 32)   9248        tf_op_layer_Max_4[0][0]
#                                                                  tf_op_layer_Mean_4[0][0]
#                                                                  tf_op_layer_Min_4[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 28, 28, 32)   9248        conv2d_24[0][0]
#                                                                  conv2d_24[1][0]
#                                                                  conv2d_24[2][0]
#                                                                  conv2d_24[3][0]
#                                                                  conv2d_24[4][0]
#                                                                  conv2d_24[5][0]
#                                                                  conv2d_24[6][0]
#                                                                  conv2d_24[7][0]
#                                                                  conv2d_24[8][0]
#                                                                  conv2d_24[9][0]
#                                                                  conv2d_24[10][0]
#                                                                  conv2d_24[11][0]
#                                                                  conv2d_24[12][0]
#                                                                  conv2d_24[13][0]
#                                                                  conv2d_24[14][0]
#                                                                  conv2d_24[15][0]
#                                                                  conv2d_24[16][0]
#                                                                  conv2d_24[17][0]
#                                                                  conv2d_24[18][0]
#                                                                  conv2d_24[19][0]
#                                                                  conv2d_24[20][0]
#                                                                  conv2d_24[21][0]
#                                                                  conv2d_24[22][0]
#                                                                  conv2d_24[23][0]
#                                                                  conv2d_24[24][0]
#                                                                  conv2d_24[25][0]
#                                                                  conv2d_24[26][0]
#                                                                  conv2d_24[27][0]
#                                                                  conv2d_24[28][0]
#                                                                  conv2d_24[29][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_150 (TensorF [(None, 28, 28, 1056 0           conv2d_26[0][0]
#                                                                  conv2d_26[1][0]
#                                                                  conv2d_26[2][0]
#                                                                  conv2d_25[0][0]
#                                                                  conv2d_25[1][0]
#                                                                  conv2d_25[2][0]
#                                                                  conv2d_25[3][0]
#                                                                  conv2d_25[4][0]
#                                                                  conv2d_25[5][0]
#                                                                  conv2d_25[6][0]
#                                                                  conv2d_25[7][0]
#                                                                  conv2d_25[8][0]
#                                                                  conv2d_25[9][0]
#                                                                  conv2d_25[10][0]
#                                                                  conv2d_25[11][0]
#                                                                  conv2d_25[12][0]
#                                                                  conv2d_25[13][0]
#                                                                  conv2d_25[14][0]
#                                                                  conv2d_25[15][0]
#                                                                  conv2d_25[16][0]
#                                                                  conv2d_25[17][0]
#                                                                  conv2d_25[18][0]
#                                                                  conv2d_25[19][0]
#                                                                  conv2d_25[20][0]
#                                                                  conv2d_25[21][0]
#                                                                  conv2d_25[22][0]
#                                                                  conv2d_25[23][0]
#                                                                  conv2d_25[24][0]
#                                                                  conv2d_25[25][0]
#                                                                  conv2d_25[26][0]
#                                                                  conv2d_25[27][0]
#                                                                  conv2d_25[28][0]
#                                                                  conv2d_25[29][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 28, 28, 64)   608320      tf_op_layer_concat_150[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 28, 28, 64)   0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 28, 28, 64)   36928       dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 28, 28, 1)    577         conv2d_28[0][0]
# ==================================================================================================
# Total params: 890,465
# Trainable params: 890,465
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # 测试正确率：

# %%
from skimage.metrics import peak_signal_noise_ratio,structural_similarity, mean_squared_error
class show_accuracy(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if epoch % 5 == 1:
      data,ans = next(test_generator)
      data = [data[x][5][np.newaxis,:,:,:] for x in range(picnum)]
      ans = ans[5]
      import matplotlib
      cmap = matplotlib.cm.gray 
      cmap.set_bad(color='black')

      pred = model.predict(data) #shape:(1,11,11,1) because last layer is conv not dense
      #pred = np.clip(pred,0,1)
      #pred = (pred-np.min(pred))/(np.max(pred)-np.min(pred))
      #pred = softmax(pred)
      pred[0,0,0,0]=0
      pred[0,-1,-1,0]=1
      ans[0,0]=0
      ans[-1,-1]=1
      for i in range(6):
        plt.subplot(231+i)
        plt.imshow(data[i][0,:,:,0],cmap=cmap)
      plt.show()
      plt.subplot(121)
      plt.imshow(pred[0,:,:,0],cmap=cmap)
      plt.colorbar()
      #ans = np.clip((ans-np.percentile(ans,10))/(np.percentile(ans,90)-np.percentile(ans,10)),0,1)
      plt.subplot(122)
      plt.imshow(ans,cmap=cmap)
      plt.colorbar()
      plt.show()
#      print('psnr',peak_signal_noise_ratio(np.clip(pred[0,:,:,0],0,1),ans))
#      print('ssim',structural_similarity(np.clip(pred[0,:,:,0],0,1),ans))
      print('mse',mean_squared_error(np.clip(pred[0,:,:,0],0,1),ans))

# %% [markdown]
# # 开始训练

# %%
# Suppress some level of logs
import logging
logging.getLogger("tensorflow").setLevel(logging.WARN)

# %%
ckpt_filename = tf.train.latest_checkpoint("/content/drive/My Drive/checkpoints/training_15_archive")
print(ckpt_filename)
model.load_weights(ckpt_filename)#,by_name=True)

# %%
checkpoint_path = "/content/drive/My Drive/checkpoints/training_20/cp-{epoch:02d}-{val_loss:.4f}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,save_weights_only=True,monitor='val_loss')#,save_best_only=True,mode='min')
show_accuracy_callback = show_accuracy()

# %%
show_accuracy_callback.on_epoch_end(epoch=1)
# Out:
# mse 0.6875855320934264

# %%
if True:
  if not os.path.exists(checkpoint_dir):
    model.fit_generator(train_generator,epochs=200,steps_per_epoch=500,validation_data=test_generator,validation_steps=50,validation_freq=1,verbose=2,callbacks=[cp_callback,show_accuracy_callback])
# Out:
# WARNING:tensorflow:From <ipython-input-19-753a140962d3>:3: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 500 steps, validate for 50 steps
# Epoch 1/200
# 500/500 - 218s - loss: 0.1472 - mse: 0.1472 - val_loss: 0.1352 - val_mse: 0.1352
# Epoch 2/200
# mse 0.15714113953718006
# 500/500 - 191s - loss: 0.1327 - mse: 0.1327 - val_loss: 0.1341 - val_mse: 0.1341
# Epoch 3/200
# 500/500 - 190s - loss: 0.1297 - mse: 0.1297 - val_loss: 0.1325 - val_mse: 0.1325
# Epoch 4/200
# 500/500 - 190s - loss: 0.1273 - mse: 0.1273 - val_loss: 0.1289 - val_mse: 0.1289
# Epoch 5/200
# 500/500 - 190s - loss: 0.1255 - mse: 0.1255 - val_loss: 0.1299 - val_mse: 0.1299
# Epoch 6/200
# 500/500 - 190s - loss: 0.1241 - mse: 0.1241 - val_loss: 0.1273 - val_mse: 0.1273
# Epoch 7/200
# mse 0.12142816930659461
# 500/500 - 192s - loss: 0.1229 - mse: 0.1229 - val_loss: 0.1286 - val_mse: 0.1286
# Epoch 8/200
# 500/500 - 190s - loss: 0.1217 - mse: 0.1217 - val_loss: 0.1273 - val_mse: 0.1273
# Epoch 9/200
# 500/500 - 190s - loss: 0.1207 - mse: 0.1207 - val_loss: 0.1265 - val_mse: 0.1265
# Epoch 10/200
# 500/500 - 190s - loss: 0.1201 - mse: 0.1201 - val_loss: 0.1263 - val_mse: 0.1263
# Epoch 11/200
# 500/500 - 190s - loss: 0.1190 - mse: 0.1190 - val_loss: 0.1263 - val_mse: 0.1263
# Epoch 12/200
# mse 0.10514591679028064
# 500/500 - 191s - loss: 0.1186 - mse: 0.1186 - val_loss: 0.1252 - val_mse: 0.1252
# Epoch 13/200
# 500/500 - 190s - loss: 0.1177 - mse: 0.1177 - val_loss: 0.1263 - val_mse: 0.1263
# Epoch 14/200
# 500/500 - 190s - loss: 0.1175 - mse: 0.1175 - val_loss: 0.1267 - val_mse: 0.1267
# Epoch 15/200
# 500/500 - 190s - loss: 0.1166 - mse: 0.1166 - val_loss: 0.1272 - val_mse: 0.1272
# Epoch 16/200
# 500/500 - 190s - loss: 0.1167 - mse: 0.1167 - val_loss: 0.1251 - val_mse: 0.1251
# Epoch 17/200
# mse 0.15064666016708672
# 500/500 - 192s - loss: 0.1161 - mse: 0.1161 - val_loss: 0.1268 - val_mse: 0.1268
# Epoch 18/200
# 500/500 - 190s - loss: 0.1151 - mse: 0.1151 - val_loss: 0.1265 - val_mse: 0.1265
# Epoch 19/200
# 500/500 - 190s - loss: 0.1148 - mse: 0.1148 - val_loss: 0.1250 - val_mse: 0.1250
# Epoch 20/200
# 500/500 - 190s - loss: 0.1142 - mse: 0.1142 - val_loss: 0.1246 - val_mse: 0.1246
# Epoch 21/200
# 500/500 - 190s - loss: 0.1138 - mse: 0.1138 - val_loss: 0.1261 - val_mse: 0.1261
# Epoch 22/200
# mse 0.13906409501302325
# 500/500 - 191s - loss: 0.1136 - mse: 0.1136 - val_loss: 0.1237 - val_mse: 0.1237
# Epoch 23/200
# 500/500 - 190s - loss: 0.1137 - mse: 0.1137 - val_loss: 0.1260 - val_mse: 0.1260
# Epoch 24/200
# 500/500 - 190s - loss: 0.1130 - mse: 0.1130 - val_loss: 0.1263 - val_mse: 0.1263
# Epoch 25/200
# 500/500 - 190s - loss: 0.1123 - mse: 0.1123 - val_loss: 0.1256 - val_mse: 0.1256
# Epoch 26/200
# 500/500 - 190s - loss: 0.1123 - mse: 0.1123 - val_loss: 0.1251 - val_mse: 0.1251
# Epoch 27/200
# mse 0.12284289040027184
# 500/500 - 192s - loss: 0.1121 - mse: 0.1121 - val_loss: 0.1255 - val_mse: 0.1255
# Epoch 28/200
# 500/500 - 190s - loss: 0.1117 - mse: 0.1117 - val_loss: 0.1263 - val_mse: 0.1263
# Epoch 29/200
# 500/500 - 190s - loss: 0.1112 - mse: 0.1112 - val_loss: 0.1261 - val_mse: 0.1261
# Epoch 30/200
# 500/500 - 190s - loss: 0.1109 - mse: 0.1109 - val_loss: 0.1256 - val_mse: 0.1256
# Epoch 31/200
# 500/500 - 190s - loss: 0.1108 - mse: 0.1108 - val_loss: 0.1245 - val_mse: 0.1245
# Epoch 32/200
# mse 0.14535635082715279
# 500/500 - 192s - loss: 0.1106 - mse: 0.1106 - val_loss: 0.1250 - val_mse: 0.1250
# Epoch 33/200
# 500/500 - 190s - loss: 0.1104 - mse: 0.1104 - val_loss: 0.1260 - val_mse: 0.1260
# Epoch 34/200
# 500/500 - 190s - loss: 0.1106 - mse: 0.1106 - val_loss: 0.1265 - val_mse: 0.1265
# Epoch 35/200
# 500/500 - 190s - loss: 0.1098 - mse: 0.1098 - val_loss: 0.1269 - val_mse: 0.1269
# Epoch 36/200
# 500/500 - 191s - loss: 0.1096 - mse: 0.1096 - val_loss: 0.1241 - val_mse: 0.1241
# Epoch 37/200
# mse 0.1536849659955327
# 500/500 - 192s - loss: 0.1095 - mse: 0.1095 - val_loss: 0.1265 - val_mse: 0.1265
# Epoch 38/200
# 500/500 - 190s - loss: 0.1090 - mse: 0.1090 - val_loss: 0.1253 - val_mse: 0.1253
# Epoch 39/200
# 500/500 - 190s - loss: 0.1093 - mse: 0.1093 - val_loss: 0.1256 - val_mse: 0.1256
# Epoch 40/200
# 500/500 - 190s - loss: 0.1089 - mse: 0.1089 - val_loss: 0.1248 - val_mse: 0.1248
# Epoch 41/200
# 500/500 - 190s - loss: 0.1086 - mse: 0.1086 - val_loss: 0.1263 - val_mse: 0.1263
# Epoch 42/200
# mse 0.11684806083536928
# 500/500 - 191s - loss: 0.1083 - mse: 0.1083 - val_loss: 0.1274 - val_mse: 0.1274
# Epoch 43/200
# 500/500 - 190s - loss: 0.1083 - mse: 0.1083 - val_loss: 0.1256 - val_mse: 0.1256
# Epoch 44/200
# 500/500 - 190s - loss: 0.1084 - mse: 0.1084 - val_loss: 0.1255 - val_mse: 0.1255
# Epoch 45/200
# 500/500 - 191s - loss: 0.1075 - mse: 0.1075 - val_loss: 0.1243 - val_mse: 0.1243
# Epoch 46/200
# 500/500 - 190s - loss: 0.1080 - mse: 0.1080 - val_loss: 0.1261 - val_mse: 0.1261
# Epoch 47/200
# mse 0.13097099403661383
# 500/500 - 191s - loss: 0.1076 - mse: 0.1076 - val_loss: 0.1259 - val_mse: 0.1259
# Epoch 48/200
# 500/500 - 190s - loss: 0.1075 - mse: 0.1075 - val_loss: 0.1269 - val_mse: 0.1269
# Epoch 49/200
# 500/500 - 190s - loss: 0.1076 - mse: 0.1076 - val_loss: 0.1262 - val_mse: 0.1262
# Epoch 50/200
# 500/500 - 190s - loss: 0.1074 - mse: 0.1074 - val_loss: 0.1258 - val_mse: 0.1258
# Epoch 51/200
# 500/500 - 190s - loss: 0.1066 - mse: 0.1066 - val_loss: 0.1243 - val_mse: 0.1243
# Epoch 52/200
# mse 0.1363841713545585
# 500/500 - 191s - loss: 0.1068 - mse: 0.1068 - val_loss: 0.1249 - val_mse: 0.1249
# Epoch 53/200
# 500/500 - 190s - loss: 0.1068 - mse: 0.1068 - val_loss: 0.1254 - val_mse: 0.1254
# Epoch 54/200
# 500/500 - 190s - loss: 0.1066 - mse: 0.1066 - val_loss: 0.1251 - val_mse: 0.1251
# Epoch 55/200
# 500/500 - 190s - loss: 0.1066 - mse: 0.1066 - val_loss: 0.1251 - val_mse: 0.1251
# Epoch 56/200
# 500/500 - 191s - loss: 0.1061 - mse: 0.1061 - val_loss: 0.1274 - val_mse: 0.1274
# Epoch 57/200
# mse 0.12776884700535387
# 500/500 - 192s - loss: 0.1058 - mse: 0.1058 - val_loss: 0.1270 - val_mse: 0.1270
# Epoch 58/200
# 500/500 - 190s - loss: 0.1062 - mse: 0.1062 - val_loss: 0.1264 - val_mse: 0.1264
# Epoch 59/200
# 500/500 - 190s - loss: 0.1057 - mse: 0.1057 - val_loss: 0.1259 - val_mse: 0.1259
# Epoch 60/200
# 500/500 - 190s - loss: 0.1054 - mse: 0.1054 - val_loss: 0.1245 - val_mse: 0.1245
# Epoch 61/200
# 500/500 - 190s - loss: 0.1057 - mse: 0.1057 - val_loss: 0.1256 - val_mse: 0.1256
# Epoch 62/200
# mse 0.11504475674627955
# 500/500 - 191s - loss: 0.1051 - mse: 0.1051 - val_loss: 0.1269 - val_mse: 0.1269
# Epoch 63/200
# 500/500 - 191s - loss: 0.1057 - mse: 0.1057 - val_loss: 0.1281 - val_mse: 0.1281
# Epoch 64/200
# 500/500 - 191s - loss: 0.1055 - mse: 0.1055 - val_loss: 0.1261 - val_mse: 0.1261
# Epoch 65/200
# 500/500 - 190s - loss: 0.1053 - mse: 0.1053 - val_loss: 0.1257 - val_mse: 0.1257
# Epoch 66/200
# 500/500 - 190s - loss: 0.1052 - mse: 0.1052 - val_loss: 0.1261 - val_mse: 0.1261
# Epoch 67/200
# mse 0.11185071970947381
# 500/500 - 192s - loss: 0.1051 - mse: 0.1051 - val_loss: 0.1274 - val_mse: 0.1274
# Epoch 68/200
# 500/500 - 190s - loss: 0.1051 - mse: 0.1051 - val_loss: 0.1273 - val_mse: 0.1273
# Epoch 69/200
# 500/500 - 190s - loss: 0.1049 - mse: 0.1049 - val_loss: 0.1260 - val_mse: 0.1260
# Epoch 70/200
# 500/500 - 190s - loss: 0.1049 - mse: 0.1049 - val_loss: 0.1243 - val_mse: 0.1243
# Epoch 71/200
# 500/500 - 190s - loss: 0.1047 - mse: 0.1047 - val_loss: 0.1261 - val_mse: 0.1261
# Epoch 72/200
# mse 0.12486805911039303
# 500/500 - 191s - loss: 0.1046 - mse: 0.1046 - val_loss: 0.1279 - val_mse: 0.1279
# Epoch 73/200
# 500/500 - 190s - loss: 0.1046 - mse: 0.1046 - val_loss: 0.1273 - val_mse: 0.1273
# Epoch 74/200
# 500/500 - 190s - loss: 0.1050 - mse: 0.1050 - val_loss: 0.1258 - val_mse: 0.1258
# Epoch 75/200
# 500/500 - 191s - loss: 0.1039 - mse: 0.1039 - val_loss: 0.1269 - val_mse: 0.1269
# Epoch 76/200
# 500/500 - 190s - loss: 0.1040 - mse: 0.1040 - val_loss: 0.1270 - val_mse: 0.1270
# Epoch 77/200
# mse 0.1086922877012316
# 500/500 - 191s - loss: 0.1041 - mse: 0.1041 - val_loss: 0.1258 - val_mse: 0.1258
# Epoch 78/200
# 500/500 - 190s - loss: 0.1037 - mse: 0.1037 - val_loss: 0.1263 - val_mse: 0.1263
# Epoch 79/200
# 500/500 - 190s - loss: 0.1040 - mse: 0.1040 - val_loss: 0.1269 - val_mse: 0.1269
# Epoch 80/200
# 500/500 - 190s - loss: 0.1039 - mse: 0.1039 - val_loss: 0.1253 - val_mse: 0.1253
# Epoch 81/200
# 500/500 - 190s - loss: 0.1037 - mse: 0.1037 - val_loss: 0.1277 - val_mse: 0.1277
# Epoch 82/200
# mse 0.14111587274155032
# 500/500 - 191s - loss: 0.1037 - mse: 0.1037 - val_loss: 0.1267 - val_mse: 0.1267
# Epoch 83/200
# 500/500 - 191s - loss: 0.1034 - mse: 0.1034 - val_loss: 0.1278 - val_mse: 0.1278
# Epoch 84/200
# 500/500 - 190s - loss: 0.1036 - mse: 0.1036 - val_loss: 0.1243 - val_mse: 0.1243
# Epoch 85/200
# 500/500 - 190s - loss: 0.1035 - mse: 0.1035 - val_loss: 0.1259 - val_mse: 0.1259
# Epoch 86/200
# 500/500 - 190s - loss: 0.1033 - mse: 0.1033 - val_loss: 0.1277 - val_mse: 0.1277
# Epoch 87/200
# mse 0.14102362624443143
# 500/500 - 191s - loss: 0.1032 - mse: 0.1032 - val_loss: 0.1282 - val_mse: 0.1282
# Epoch 88/200
# 500/500 - 190s - loss: 0.1032 - mse: 0.1032 - val_loss: 0.1278 - val_mse: 0.1278
# Epoch 89/200
# 500/500 - 190s - loss: 0.1030 - mse: 0.1030 - val_loss: 0.1278 - val_mse: 0.1278
# Epoch 90/200
# 500/500 - 190s - loss: 0.1033 - mse: 0.1033 - val_loss: 0.1271 - val_mse: 0.1271
# Epoch 91/200
# 500/500 - 190s - loss: 0.1030 - mse: 0.1030 - val_loss: 0.1260 - val_mse: 0.1260
# Epoch 92/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_v2.py in on_epoch(self, epoch, mode)
#     766     try:
# --> 767       yield epoch_logs
#     768     finally:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     567     else:
# --> 568       result = self._call(*args, **kwds)
#     569
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     598       # defunned version which is guaranteed to never create variables.
# --> 599       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     600     elif self._stateful_fn is not None:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    2362       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2363     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2364
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1610                            resource_variable_ops.BaseResourceVariable))),
# -> 1611         self.captured_inputs)
#    1612
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-753a140962d3> in <module>()
#       1 if True:
#       2   if not os.path.exists(checkpoint_dir):
# ----> 3     model.fit_generator(train_generator,epochs=200,steps_per_epoch=500,validation_data=test_generator,validation_steps=50,validation_freq=1,verbose=2,callbacks=[cp_callback,show_accuracy_callback])
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/util/deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1304         use_multiprocessing=use_multiprocessing,
#    1305         shuffle=shuffle,
# -> 1306         initial_epoch=initial_epoch)
#    1307
#    1308   @deprecation.deprecated(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     395                       total_epochs=1)
#     396                   cbks.make_logs(model, epoch_logs, eval_result, ModeKeys.TEST,
# --> 397                                  prefix='val_')
#     398
#     399     return model.history
#
# /usr/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      97                 value = type()
#      98             try:
# ---> 99                 self.gen.throw(type, value, traceback)
#     100             except StopIteration as exc:
#     101                 # Suppress StopIteration *unless* it's the same exception that
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_v2.py in on_epoch(self, epoch, mode)
#     769       if mode == ModeKeys.TRAIN:
#     770         # Epochs only apply to `fit`.
# --> 771         self.callbacks.on_epoch_end(epoch, epoch_logs)
#     772       self.progbar.on_epoch_end(epoch, epoch_logs)
#     773
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#     300     logs = logs or {}
#     301     for callback in self.callbacks:
# --> 302       callback.on_epoch_end(epoch, logs)
#     303
#     304   def on_train_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#     990           self._save_model(epoch=epoch, logs=logs)
#     991       else:
# --> 992         self._save_model(epoch=epoch, logs=logs)
#     993     if self.model._in_multi_worker_mode():
#     994       # For multi-worker training, back up the weights and current training
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/callbacks.py in _save_model(self, epoch, logs)
#    1009                   int) or self.epochs_since_last_save >= self.period:
#    1010       self.epochs_since_last_save = 0
# -> 1011       filepath = self._get_file_path(epoch, logs)
#    1012
#    1013       try:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/callbacks.py in _get_file_path(self, epoch, logs)
#    1053     if not self.model._in_multi_worker_mode(
#    1054     ) or multi_worker_util.should_save_checkpoint():
# -> 1055       return self.filepath.format(epoch=epoch + 1, **logs)
#    1056     else:
#    1057       # If this is multi-worker training, and this worker should not
#
# KeyError: 'val_loss'

# %% [markdown]
# # 验证模型

# %%
def predict_pic(xpics,model):
  # xpic: array of 5 with size(22,52,1)
  picout = np.zeros((picsizex*enhance,picsizey*enhance),dtype=np.float32)
  piclayer = np.zeros((picsizex*enhance,picsizey*enhance),dtype=int)
  for posx in range(0,picsizex+1-datasizex):
    for posy in range(0,picsizey+1-datasizey):
      dataout = [pic[np.newaxis,posx:posx+datasizex,posy:posy+datasizey,:] for pic in xpics]
      pred = model.predict(dataout)
      picout[posx*enhance:(posx+datasizex)*enhance,posy*enhance:(posy+datasizey)*enhance] += pred[0,:,:,0]
      piclayer[posx*enhance:(posx+datasizex)*enhance,posy*enhance:(posy+datasizey)*enhance] += np.ones((datasizex*enhance,datasizey*enhance),dtype=int)
  picout /= piclayer
  return picout

# %%
data,ans = next(test_pic_generator)

import matplotlib
cmap = matplotlib.cm.gray 
cmap.set_bad(color='black')

pred = predict_pic(data,model)

for i in range(6):
  plt.subplot(231+i)
  b,g,r = cv2.split(data[i])       # get b,g,r
  rgb_img = cv2.merge([r,g,b])     # switch it to rgb
  plt.imshow(rgb_img)

plt.show()      
pred[0,0]=0
pred[-1,-1]=1
ans[0,0]=0
ans[-1,-1]=1
plt.subplot(121)
plt.imshow(pred,cmap=cmap)
plt.colorbar()
#ans = np.clip((ans-np.percentile(ans,10))/(np.percentile(ans,90)-np.percentile(ans,10)),0,1)
plt.subplot(122)
plt.imshow(ans,cmap=cmap)
plt.colorbar()
plt.show()
#      print('psnr',peak_signal_noise_ratio(np.clip(pred[0,:,:,0],0,1),ans))
#      print('ssim',structural_similarity(np.clip(pred[0,:,:,0],0,1),ans))
#print('mse',mean_squared_error(np.clip(pred,0,1),ans))
